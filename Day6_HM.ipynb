# %%
import pandas as pd

# %%
df = pd.read_csv("/content/data.csv", encoding='latin1')
df
# Out:
# <ipython-input-9-a433be7183f8>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/data.csv", encoding='latin1')
#        stn_code       sampling_date           state   location agency  \
# 0         150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1         151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2         152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3         150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4         151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# ...         ...                 ...             ...        ...    ...
# 184481      NaN            15-12-07  Madhya Pradesh     Ujjain    NaN
# 184482      NaN            19-12-07  Madhya Pradesh     Ujjain    NaN
# 184483      NaN            22-12-07  Madhya Pradesh     Ujjain    NaN
# 184484      NaN            26-12-07  Madhya Pradesh     Ujjain    NaN
# ...

# %%
import pandas as pd
import seaborn as sns
data=df[df['state'] == 'Goa']
sns.catplot(data=data,x='location',y='so2',hue='location')
